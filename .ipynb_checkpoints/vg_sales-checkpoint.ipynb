# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests as r
from bs4 import BeautifulSoup

#Importing, cleaning, sorting and indexing data

#web scraping wikipedia page for highest selling video games
url = 'https://en.wikipedia.org/wiki/List_of_best-selling_video_games'
unparsed_wiki = r.get(url)

#parsing data into a beautifulsoup object
soup = BeautifulSoup(unparsed_wiki.text, 'html.parser')
parsed_wiki = soup.find('table',{'class':"wikitable"})

#converting parsed data into a dataframe
videogame_sales = pd.read_html(str(parsed_wiki))
vg_sales = pd.DataFrame(videogame_sales[0])

#dropping 'Ref' column. inplace = True so to not create new dataframe
vg_sales.drop(columns = ['Ref'], inplace=True)
#renaming columns to remove superfluous syntax, setting index and replacing value
vg_sales.rename(
    columns={
        "Platform(s)": "Platform",
        "Initial release date": "date",
        "Developer(s)[b]": "Developer",
        "Publisher(s)[b]": "Publisher"
    },
    inplace=True
)
vg_sales.set_index("Title", inplace = True)
vg_sales.loc['Minecraft', 'date'] = ('November 18, 2011')

#importing data from two .csv (video game inspired movies)
highest_gross_movies = pd.read_csv('/Users/jaimepira/Desktop/highest_gross_video_game_films.csv')
video_game_movies = pd.read_csv('/Users/jaimepira/Desktop/video_game_films.csv')

#merging the two df to create a more complete list of movies inspired by video games
vg_movies = pd.merge(video_game_movies, highest_gross_movies, how = 'outer')
#removing duplicates and irrelevant data columns
vg_movies.drop_duplicates(subset = "Title")
vg_movies.drop(columns = ['Rank', 'Peak', 'gross', 'Date', 'Format'], inplace = True)

#sorting vg_movies by box office returns and indexing by movie in descending order
vg_movies.sort_values("Worldwide box office", ascending = False, inplace = True)
vg_movies.set_index("Title", inplace = True)

#Subsetting and plotting data

#plotting vg_sales 
#subsetting first due to number of entries
top10_vgsales = vg_sales[:10]
sns.barplot(x=top10_vgsales.index, y='Sales', data=top10_vgsales)
plt.xlabel('Title')
plt.ylabel('Sales (in hundreds of mil)')
plt.xticks(rotation=70) 
plt.show()

sns.barplot(x='Developer', y='Sales', data=top10_vgsales)
plt.xlabel('Developers')
plt.ylabel('Sales (in hundreds of mil)')
plt.xticks(rotation=70) 
plt.show()



print(top10_vgsales_developer.head(40))
# Out:
#                                                  Sales               Series  \
# Title
# Minecraft                                    238000000            Minecraft
# Grand Theft Auto V                           180000000     Grand Theft Auto
# Tetris (EA)                                  100000000               Tetris
# Wii Sports                                    82900000                  Wii
# PUBG: Battlegrounds                           75000000        PUBG Universe
# Mario Kart 8 / Deluxe                         62250000           Mario Kart
# Super Mario Bros.                             58000000          Super Mario
# Red Dead Redemption 2                         53000000             Red Dead
# The Witcher 3: Wild Hunt                      50000000          The Witcher
# Overwatch                                     50000000            Overwatch
# Tetris (1989)[f]                              48000000               Tetris
# Pokémon Red / Green / Blue / Yellow           47520000              Pokémon
# Terraria                                      44500000                 None
# Wii Fit / Plus                                43800000                  Wii
# Animal Crossing: New Horizons                 42210000      Animal Crossing
# Pac-Man                                       42071635              Pac-Man
# Human: Fall Flat                              40000000                 None
# Mario Kart Wii                                37380000           Mario Kart
# Wii Sports Resort                             33140000                  Wii
# The Legend of Zelda: Breath of the Wild       31510000  The Legend of Zelda
# Super Smash Bros. Ultimate                    31090000    Super Smash Bros.
# New Super Mario Bros.                         30800000          Super Mario
# New Super Mario Bros. Wii                     30320000          Super Mario
# Call of Duty: Modern Warfare                  30000000         Call of Duty
# Diablo III                                    30000000               Diablo
# Pokémon Gold / Silver / Crystal               29490000              Pokémon
# Duck Hunt                                     28300000                 None
# Wii Play                                      28020000                  Wii
# The Walking Dead                              28000000     The Walking Dead
# Grand Theft Auto: San Andreas                 27500000     Grand Theft Auto
# Borderlands 2                                 27000000          Borderlands
# Super Mario World                             26662500          Super Mario
# Call of Duty: Modern Warfare 3                26500000         Call of Duty
# FIFA 18                                       26400000                 FIFA
# Call of Duty: Black Ops                       26200000         Call of Duty
# Pokémon Sword / Shield                        25820000              Pokémon
# Super Mario Odyssey                           25760000          Super Mario
# Pokémon Sun / Moon / Ultra Sun / Ultra Moon   25450000              Pokémon
# Grand Theft Auto IV                           25000000     Grand Theft Auto
# Pokémon Diamond / Pearl / Platinum            24730000              Pokémon
#
#                                                     Platform  \
# Title
# Minecraft                                     Multi-platform
# Grand Theft Auto V                            Multi-platform
# Tetris (EA)                                   Multi-platform
# Wii Sports                                               Wii
# PUBG: Battlegrounds                           Multi-platform
# Mario Kart 8 / Deluxe                         Wii U / Switch
# Super Mario Bros.                             Multi-platform
# Red Dead Redemption 2                         Multi-platform
# The Witcher 3: Wild Hunt                      Multi-platform
# Overwatch                                     Multi-platform
# Tetris (1989)[f]                              Game Boy / NES
# Pokémon Red / Green / Blue / Yellow           Multi-platform
# Terraria                                      Multi-platform
# Wii Fit / Plus                                           Wii
# Animal Crossing: New Horizons                Nintendo Switch
# Pac-Man                                       Multi-platform
# Human: Fall Flat                              Multi-platform
# Mario Kart Wii                                           Wii
# Wii Sports Resort                                        Wii
# The Legend of Zelda: Breath of the Wild       Wii U / Switch
# Super Smash Bros. Ultimate                   Nintendo Switch
# New Super Mario Bros.                            Nintendo DS
# New Super Mario Bros. Wii                                Wii
# Call of Duty: Modern Warfare                  Multi-platform
# Diablo III                                    Multi-platform
# Pokémon Gold / Silver / Crystal               Game Boy Color
# Duck Hunt                                                NES
# Wii Play                                                 Wii
# The Walking Dead                              Multi-platform
# Grand Theft Auto: San Andreas                 Multi-platform
# Borderlands 2                                 Multi-platform
# Super Mario World                             Multi-platform
# Call of Duty: Modern Warfare 3                Multi-platform
# FIFA 18                                       Multi-platform
# Call of Duty: Black Ops                       Multi-platform
# Pokémon Sword / Shield                       Nintendo Switch
# Super Mario Odyssey                          Nintendo Switch
# Pokémon Sun / Moon / Ultra Sun / Ultra Moon     Nintendo 3DS
# Grand Theft Auto IV                           Multi-platform
# Pokémon Diamond / Pearl / Platinum               Nintendo DS
#
#                                                            date  \
# Title
# Minecraft                                     November 18, 2011
# Grand Theft Auto V                           September 17, 2013
# Tetris (EA)                                  September 12, 2006
# Wii Sports                                    November 19, 2006
# PUBG: Battlegrounds                           December 20, 2017
# Mario Kart 8 / Deluxe                              May 29, 2014
# Super Mario Bros.                            September 13, 1985
# Red Dead Redemption 2                          October 26, 2018
# The Witcher 3: Wild Hunt                           May 19, 2015
# Overwatch                                          May 24, 2016
# Tetris (1989)[f]                                  June 14, 1989
# Pokémon Red / Green / Blue / Yellow           February 27, 1996
# Terraria                                           May 16, 2011
# Wii Fit / Plus                                 December 1, 2007
# Animal Crossing: New Horizons                    March 20, 2020
# Pac-Man                                            May 22, 1980
# Human: Fall Flat                                  July 22, 2016
# Mario Kart Wii                                   April 10, 2008
# Wii Sports Resort                                 June 25, 2009
# The Legend of Zelda: Breath of the Wild           March 3, 2017
# Super Smash Bros. Ultimate                     December 7, 2018
# New Super Mario Bros.                              May 15, 2006
# New Super Mario Bros. Wii                     November 11, 2009
# Call of Duty: Modern Warfare                   October 25, 2019
# Diablo III                                         May 16, 2012
# Pokémon Gold / Silver / Crystal               November 21, 1999
# Duck Hunt                                        April 21, 1984
# Wii Play                                       December 2, 2006
# The Walking Dead                                 April 24, 2012
# Grand Theft Auto: San Andreas                  October 26, 2004
# Borderlands 2                                September 18, 2012
# Super Mario World                             November 21, 1990
# Call of Duty: Modern Warfare 3                 November 8, 2011
# FIFA 18                                      September 29, 2017
# Call of Duty: Black Ops                        November 9, 2010
# Pokémon Sword / Shield                        November 15, 2019
# Super Mario Odyssey                            October 27, 2017
# Pokémon Sun / Moon / Ultra Sun / Ultra Moon   November 18, 2016
# Grand Theft Auto IV                              April 29, 2008
# Pokémon Diamond / Pearl / Platinum           September 28, 2006
#
#                                                                         Developer  \
# Title
# Minecraft                                                          Mojang Studios
# Grand Theft Auto V                                                 Rockstar North
# Tetris (EA)                                                             EA Mobile
# Wii Sports                                                           Nintendo EAD
# PUBG: Battlegrounds                                              PUBG Corporation
# Mario Kart 8 / Deluxe                        Nintendo EAD / Nintendo EPD (Deluxe)
# Super Mario Bros.                                                   Nintendo R&D4
# Red Dead Redemption 2                                            Rockstar Studios
# The Witcher 3: Wild Hunt                                           CD Projekt Red
# Overwatch                                                  Blizzard Entertainment
# Tetris (1989)[f]                                                    Nintendo R&D1
# Pokémon Red / Green / Blue / Yellow                                    Game Freak
# Terraria                                                                 Re-Logic
# Wii Fit / Plus                                                       Nintendo EAD
# Animal Crossing: New Horizons                                        Nintendo EPD
# Pac-Man                                                                     Namco
# Human: Fall Flat                                                  No Brakes Games
# Mario Kart Wii                                                       Nintendo EAD
# Wii Sports Resort                                                    Nintendo EAD
# The Legend of Zelda: Breath of the Wild                              Nintendo EPD
# Super Smash Bros. Ultimate                       Bandai Namco Studios / Sora Ltd.
# New Super Mario Bros.                                                Nintendo EAD
# New Super Mario Bros. Wii                                            Nintendo EAD
# Call of Duty: Modern Warfare                                        Infinity Ward
# Diablo III                                                 Blizzard Entertainment
# Pokémon Gold / Silver / Crystal                                        Game Freak
# Duck Hunt                                                           Nintendo R&D1
# Wii Play                                                             Nintendo EAD
# The Walking Dead                                                   Telltale Games
# Grand Theft Auto: San Andreas                                      Rockstar North
# Borderlands 2                                                    Gearbox Software
# Super Mario World                                                    Nintendo EAD
# Call of Duty: Modern Warfare 3                       Infinity Ward / Sledgehammer
# FIFA 18                                                              EA Vancouver
# Call of Duty: Black Ops                                                  Treyarch
# Pokémon Sword / Shield                                                 Game Freak
# Super Mario Odyssey                                                  Nintendo EPD
# Pokémon Sun / Moon / Ultra Sun / Ultra Moon                            Game Freak
# Grand Theft Auto IV                                                Rockstar North
# Pokémon Diamond / Pearl / Platinum                                     Game Freak
#
#                                                                   Publisher
# Title
# Minecraft                                                    Mojang Studios
# Grand Theft Auto V                                           Rockstar Games
# Tetris (EA)                                                 Electronic Arts
# Wii Sports                                                         Nintendo
# PUBG: Battlegrounds                                                 Krafton
# Mario Kart 8 / Deluxe                                              Nintendo
# Super Mario Bros.                                                  Nintendo
# Red Dead Redemption 2                                        Rockstar Games
# The Witcher 3: Wild Hunt                                         CD Projekt
# Overwatch                                            Blizzard Entertainment
# Tetris (1989)[f]                                                   Nintendo
# Pokémon Red / Green / Blue / Yellow                                Nintendo
# Terraria                                               Re-Logic / 505 Games
# Wii Fit / Plus                                                     Nintendo
# Animal Crossing: New Horizons                                      Nintendo
# Pac-Man                                                               Namco
# Human: Fall Flat                                              Curve Digital
# Mario Kart Wii                                                     Nintendo
# Wii Sports Resort                                                  Nintendo
# The Legend of Zelda: Breath of the Wild                            Nintendo
# Super Smash Bros. Ultimate                                         Nintendo
# New Super Mario Bros.                                              Nintendo
# New Super Mario Bros. Wii                                          Nintendo
# Call of Duty: Modern Warfare                                     Activision
# Diablo III                                           Blizzard Entertainment
# Pokémon Gold / Silver / Crystal                                    Nintendo
# Duck Hunt                                                          Nintendo
# Wii Play                                                           Nintendo
# The Walking Dead                                             Telltale Games
# Grand Theft Auto: San Andreas                                Rockstar Games
# Borderlands 2                                                      2K Games
# Super Mario World                                                  Nintendo
# Call of Duty: Modern Warfare 3                                   Activision
# FIFA 18                                                           EA Sports
# Call of Duty: Black Ops                                          Activision
# Pokémon Sword / Shield                       Nintendo / The Pokémon Company
# Super Mario Odyssey                                                Nintendo
# Pokémon Sun / Moon / Ultra Sun / Ultra Moon  Nintendo / The Pokémon Company
# Grand Theft Auto IV                                          Rockstar Games
# Pokémon Diamond / Pearl / Platinum           Nintendo / The Pokémon Company
